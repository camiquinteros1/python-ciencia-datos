# %% [markdown]
# <a href="https://colab.research.google.com/github/camiquinteros1/python-ciencia-datos/blob/main/primerosPasos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#este es un comentario en python

print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# Esto es un comentario en Colab. salgo del bloque de codigo. Lo escribimos en nuestro block de notas.

# %%
"""comentarios en py"""
#comentarios en py

print("Hola")
# Out:
# Hola

# %% [markdown]
# ![fondo.png](data:image/png;base64,...)
